# %% [markdown]
# ## FASTQC (Análisis de calidad de secuencias)
# ---

# %%
#!/bin/bash
#SBATCH -p cicese
#SBATCH --job-name=fastqc
#SBATCH --output=fastqc-%j.log
#SBATCH --error=fastqc-%j.err
#SBATCH -N 1
#SBATCH --ntasks-per-node=8
#SBATCH -t 6-00:00:00


export PATH=$PATH:/LUSTRE/apps/bioinformatica/FastQC_v0.11.7/:$PATH

module load gcc-7.2.0

fastqc ../secuencias/*.fastq -t 8 -o ./

# %% [markdown]
# ##### Para realizar multiqc en el cluster se debe colocar el module conda-2023 y la instrucción de multiqc
# multiqc ../*.zip -o ./ --data-format tsv --export --title "Analisis pre trimming"

# %% [markdown]
# ---
# Trimmomatic
# ---

# %%
#!/bin/bash
#########################################################
#TRIMOMMATIC ##prueba 2

## Directivas
#SBATCH --job-name=qtrim
#SBATCH --output=trimmomatic-%j.log
#SBATCH --error=trimmomatic-%j.err
#SBATCH -N 1
#SBATCH --mem=20GB
#SBATCH --ntasks-per-node=8
#SBATCH -t 6-00:00:00
#SBATCH -p cicese


# Ruta a TRIMMOMATIC
TRIMMOMATIC=/LUSTRE/apps/bioinformatica/Trimmomatic-0.39

#Ruta al archivo con los adaptadores
trueseq="$TRIMMOMATIC/adapters/TruSeq3-PE-2.fa"
trueseq="$TRIMMOMATIC/adapters/TruSeq3-PE.fa"
trueseq="$TRIMMOMATIC/adapters/TruSeq2-PE.fa"

cd ${SLURM_SUBMIT_DIR}

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_C1_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_C1_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_C1.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_C2_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_C2_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_C2.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_C3_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_C3_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_C3.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_F1_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_F1_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_F1.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_F2_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_F2_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_F2.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/BLA_F3_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/BLA_F3_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout BLA_F3.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_C1_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_C1_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_C1.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_C2_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_C2_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_C2.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_C3_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_C3_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_C3.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_F1_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_F1_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_F1.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_F2_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_F2_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_F2.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

java -jar $TRIMMOMATIC/trimmomatic-0.39.jar PE ../raw/LOL_F3_CKDL230014589-1A_HJLMVCCX2_L5_1.fq.gz ../raw/LOL_F3_CKDL230014589-1A_HJLMVCCX2_L5_2.fq.gz -baseout LOL_F3.fq.gz \
ILLUMINACLIP:$trueseq:2:30:10:8:true SLIDINGWINDOW:4:15 CROP:110 HEADCROP:10 MINLEN:36

exit 0

# %% [markdown]
# ###### Para conocer más sobre los comandos y flags [Manual trimmomatic](http://www.usadellab.org/cms/uploads/supplementary/Trimmomatic/TrimmomaticManual_V0.32.pdf)

# %% [markdown]
# ---
# ## Trinity (Ensamble de novo)
# ---

# %%
#!/bin/bash

# Directivas
#SBATCH --job-name=Trinity-denovo # nombre del trabajo que aparecera
#SBATCH --output=slurm-%j.log # salida estandar num de trabajo
#SBATCH --error=slurm-%j.err # salida estandar de error
#SBATCH --nodes 2 # número de nodos
#SBATCH --mem=100GB # RAM 1GB por cada millon de reads
#SBATCH --ntasks-per-node=24 # número de tareas por nodo
#SBATCH -t 6-00:00:00 # número maximo
#SBATCH -p cicese #cola


#export some soft
export PATH=$PATH:/LUSTRE/apps/bioinformatica/bowtie2/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/samtools-1.17/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/jellyfish-2.3.0/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/salmon/bin/
module load conda-2023
module load trinityrnaseq-v2.15.1

#my vars

PH=`pwd`
R1="$PH/R1.fastq.gz"
R2="$PH/R2.fastq.gz"
OUTDIR="Trinity_ensamble"
LIBT="RF"
Trinity --no_version_check --seqType fq --max_memory 100G \
--no_bowtie \
--CPU 24 --left $R1 --right $R2 \
--normalize_reads \
--output $OUTDIR
#--full_cleanup"

# see the time spent
START=`date +%s`

# Run trinity
###$TRINITY  $PARM

END=`date +%s`

RUNTIME=$(($END-$START))

echo "run time -> $RUNTIME"

# %% [markdown]
# ###### Para conocer más sobre los comandos y flags [Trinity](https://github.com/trinityrnaseq/trinityrnaseq/wiki)

# %% [markdown]
# #### Una vez que se realiza el análisis, se limpian las lecturas y se realiza el ensamble, se debe revisar la calidad con la que se hizo dicho ensamble y para ello se usan herramientas como transrate o busco

# %% [markdown]
# ---
# Transrate/Ruby
# ---

# %%
#!/bin/bash

#SBATCH -p cicese
#SBATCH --job-name=tst-rvm
#SBATCH --output=ruby-%j.log
#SBATCH --error=ruby-%j.err
#SBATCH -N 1
#SBATCH --mem=100GB
#SBATCH --ntasks-per-node=24
#SBATCH -t 06-00:00:00

##se deben concatenar todas las trimm_p forward en un archivo y las reverse en otro

TRANSRATE=/LUSTRE/apps/bioinformatica/ruby2/ruby-2.2.0/bin
ENSAMBLE="../Trinity.fasta"
R1="../R1.fastq.gz"
R2="../R2.fastq.gz"

cd $SLURM_SUBMIT_DIR

export PATH=/LUSTRE/apps/bioinformatica/.local/bin:$PATH
export PATH=/LUSTRE/apps/bioinformatica/ruby2/ruby-2.2.0/bin:$PATH
export LD_LIBRARY_PATH=/LUSTRE/apps/bioinformatica/ruby2/ruby-2.2.0/lib:$LD_LIBRARY_PATH


$TRANSRATE/transrate \
--assembly $ENSAMBLE \
--left $R1 \
--right $R2 \
--threads 8 \
--output gcontigs

# %% [markdown]
# ---
# RSEM
# ---
# Análisis de expresión diferencial con RSEM, en una de las utilidades de trinity estan las opciones de alineación-estimación de la abundacia y estimación de la abundacia de matrices.

# %% [markdown]
# ##### align_and_estimate_abundance.pl

# %%
#!/bin/bash
#SBATCH -p cicese
#SBATCH --job-name=rsem
#SBATCH --output=rsem-%j.log
#SBATCH --error=rsem-%j.err
#SBATCH -N 1
#SBATCH --mem=100GB
#SBATCH --ntasks-per-node=24
#SBATCH -t 6-00:00:00
#SBATCH --exclusive

#export some soft
export PATH=$PATH:/LUSTRE/apps/bioinformatica/bowtie2/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/samtools-1.17/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/jellyfish-2.3.0/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/salmon/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/RSEM/bin
module load conda-2023
module load trinityrnaseq-v2.15.1

UTIL=/LUSTRE/apps/bioinformatica/trinityrnaseq-v2.15.1

cd $SLURM_SUBMIT_DIR
$UTIL/util/align_and_estimate_abundance.pl \
--seqType fq \
--samples_file samples.txt \
--transcripts good.Trinity.fasta \
--est_method RSEM \
--aln_method bowtie2 \
--trinity_mode \
--prep_reference \
--output_dir RSEM_outdir \
--thread_count=24 

exit 0

# %% [markdown]
# ##### align_and_estimate_abundance.pl

# %%
#!/bin/bash
#SBATCH -p cicese
#SBATCH --job-name=rsem
#SBATCH --output=rsem-%j.log
#SBATCH --error=rsem-%j.err
#SBATCH -N 1
#SBATCH --mem=100GB
#SBATCH --ntasks-per-node=24
#SBATCH -t 6-00:00:00
#SBATCH --exclusive

#export some soft
export PATH=$PATH:/LUSTRE/apps/bioinformatica/bowtie2/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/samtools-1.17/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/jellyfish-2.3.0/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/salmon/bin/
export PATH=$PATH:/LUSTRE/apps/bioinformatica/RSEM/bin
module load conda-2023
module load trinityrnaseq-v2.15.1

UTIL=/LUSTRE/apps/bioinformatica/trinityrnaseq-v2.15.1

cd $SLURM_SUBMIT_DIR
$UTIL/util/abundance_estimates_to_matrix.pl \
--est_method RSEM \ #el metodo que se usara puede ser RSEM/Kallisto/Salmon
./Silvestres_BLA_C1/RSEM.isoforms.results ../Silvestres_BLA_C2_RSEM.isoforms.results ../Silvestres_BLA_C3/RSEM.isoforms.results \
./Silvestres_BLA_F1/RSEM.isoforms.results ../Silvestres_BLA_F2/RSEM.isoforms.results ../Silvestres_BLA_F3/RSEM.isoforms.results \
./Silvestres_LOL_C1/RSEM.isoforms.results ../Silvestres_LOL_C2/RSEM.isoforms.results ../Silvestres_LOL_C3/RSEM.isoforms.results \
./Silvestres_LOL_F1/RSEM.isoforms.results ../Silvestres_LOL_F2/RSEM.isoforms.results ../Silvestres_LOL_F3/RSEM.isoforms.results \
--name_sample_by_basedir \ #Nombra la columna de la muestra por nombre del directorio en lugar del archivo predeterminado
--gene_trans_map good.Trinity.fasta.gene_trans_map \ ##el archivo sale del analisis anterior de abundance

exit 0

# %% [markdown]
# ---
# Trinotate (Anotación)
# ---
# Se utilizó una base de datos del Dr.Tripp para no generar una nueva, se buscaron y definieron cada una de las rutas de paqueterías y programas

# %%
#!/bin/bash
### Directivas
#SBATCH -p cicese
#SBATCH --job-name=Anotacion
#SBATCH --ntasks-per-node=8
#SBATCH -N 1
#SBATCH --mem=20GB
#SBATCH --output=anotacion-%j.log
#SBATCH --error=anotacion-%j.err
#SBATCH -t 06-00:00:00

BLAST=/LUSTRE/apps/bioinformatica/ncbi-blast-2.13.0+/bin 
DBS=/LUSTRE/bioinformatica_data/genomica_funcional/tripp/DATABASES

#paqueterias
PATH=$PATH://LUSTRE/apps/bioinformatica/Trinotate/PerlLib
PATH=$PATH:/LUSTRE/bioinformatica_data/genomica_funcional/apps/Trinotate-Trinotate-v4.0.1
PATH=$PATH://LUSTRE/apps/bioinformatica/Trinotate/util/admin
UTILS=/LUSTRE/apps/bioinformatica/trinityrnaseq-v2.15.1/util/support_scripts

#programas 
export PATH=$PATH:/LUSTRE/apps/bioinformatica/ncbi-blast-2.13.0+/bin
export PATH=$PATH:/LUSTRE/bioinformatica_data/genomica_funcional/apps/infernal-1.1.4/src
export PATH=$PATH:/LUSTRE/bioinformatica_data/genomica_funcional/apps/infernal-1.1.4
export PATH=$PATH:/LUSTRE/apps/bioinformatica/RSEM/bin/samtools-1.3/
export PATH=$PATH:/LUSTRE/bioinformatica_data/genomica_funcional/apps/hmmer-3.3.2/src
export PATH=$PATH:/LUSTRE/bioinformatica_data/genomica_funcional/tripp/apps/tmhmm-2.0c/bin
export PATH=$PATH:/LUSTRE/apps/bioinformatica/Trinotate
export PATH=$PATH:/LUSTRE/apps/bioinformatica/TransDecoder-v5.7.0

echo "Ejecuntandose la anotacion funcional"
echo "Fecha de inicio: `date`"
v1=`date`

cd ${SLURM_SUBMIT_DIR}

echo "Blastx"
echo "inicio BlastX: `date`"

#Cambiar de nombre el ensamble para evitar nombres de archivos muy largos

mv good.Trinity.fasta Trinity.fasta


$BLAST/blastx -query Trinity.fasta -db $DBS/uniprot_sprot.pep -num_threads 8 -max_target_seqs 1 -evalue 1E-05 -outfmt 6 > Blastx_swissprot.outfmt6

echo "Resultados de Blastx se guardaron como BlastX_swissprot.outfmt6"

#relacion de isoformas y genes

echo "generacion de gene_trans_map"

$UTILS/get_Trinity_gene_to_trans_map.pl Trinity.fasta > Trinity.gene_trans_map

#identificacion de regiones codificantes

echo "Identificacion de regiones codificantes con transdecoder"
echo "inicio Transdecoder: `date`"

TransDecoder.LongOrfs -t Trinity.fasta --gene_trans_map Trinity.gene_trans_map > transdecoder.log 

#Predecir probables ORF codificantes
echo "Predecir probables ORF codificantes: `date`"

TransDecoder.Predict -t Trinity.fasta --cpu 8 >> transdecoder.log 

#BlastP

echo "Inicio de BlastP: `date`"

$BLAST/blastp -query Trinity.fasta.transdecoder.pep -db $DBS/uniprot_sprot.pep -num_threads 8 -max_target_seqs 1 -outfmt 6 -evalue 1e-5 > Blastp_swissprot.outfmt6

echo "se genero el archivo BlastP_swissprot.outfmt6 `date`"          
#Identificacion de dominios proteicos con HMMSCAN                    
hmmscan --cpu 8 --domtblout TrinotatePFAM.out $DBS/Pfam-A.hmm Trinity.fasta.transdecoder.pep

echo "hmmscan `date`"

#Prediccion de senhales peptidicas
signalp -f short -n signalp.out Trinity.fasta.transdecoder.pep

#Prediccion de dominios transmembranales
tmhmm --short < Trinity.fasta.transdecoder.pep > tmhmm.out 

echo "tmhmm.out: `date`"


###final e imprimir fecha###
echo "Tiempo de inicio: $v1 "
echo "Tiempo final: `date`"

exit 0

# %% [markdown]
# ###### Para conocer más sobre los comandos y flags [Trinotate](https://github.com/Trinotate/Trinotate.github.io/blob/master/deprecated/index.asciidoc)
# ***Falta el programa SignalP
